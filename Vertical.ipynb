# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmeterdem/FLOWERFLOPEN/blob/main/Vertical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kütüphaneler

# %%
# !pip install -q flwr[simulation] flwr_datasets[vision] torch torchvision matplotlib scikit-learn numpy pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 18.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.3 which is incompatible.

# %% [markdown]
# Client

# %% [markdown]
# Task

# %%
import torch.nn as nn
import numpy as np
import pandas as pd


def _bin_age(age_series):
    bins = [-np.inf, 10, 40, np.inf]
    labels = ["Child", "Adult", "Elderly"]
    return (
        pd.cut(age_series, bins=bins, labels=labels, right=True)
        .astype(str)
        .replace("nan", "Unknown")
    )


def _extract_title(name_series):
    titles = name_series.str.extract(" ([A-Za-z]+)\.", expand=False)
    rare_titles = {
        "Lady",
        "Countess",
        "Capt",
        "Col",
        "Don",
        "Dr",
        "Major",
        "Rev",
        "Sir",
        "Jonkheer",
        "Dona",
    }
    titles = titles.replace(list(rare_titles), "Rare")
    titles = titles.replace({"Mlle": "Miss", "Ms": "Miss", "Mme": "Mrs"})
    return titles


def _create_features(df):
    # Convert 'Age' to numeric, coercing errors to NaN
    df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
    df["Age"] = _bin_age(df["Age"])
    df["Cabin"] = df["Cabin"].str[0].fillna("Unknown")
    df["Title"] = _extract_title(df["Name"])
    df.drop(columns=["PassengerId", "Name", "Ticket"], inplace=True)
    all_keywords = set(df.columns)
    df = pd.get_dummies(
        df, columns=["Sex", "Pclass", "Embarked", "Title", "Cabin", "Age"]
    )
    return df, all_keywords


def get_partitions_and_label():
    df = pd.read_csv("_static/data/train.csv")
    processed_df = df.dropna(subset=["Embarked", "Fare"]).copy()
    processed_df, all_keywords = _create_features(processed_df)
    raw_partitions = _partition_data(processed_df, all_keywords)

    partitions = []
    for partition in raw_partitions:
        partitions.append(partition.drop("Survived", axis=1))
    return partitions, processed_df["Survived"].values


def _partition_data(df, all_keywords):
    partitions = []
    keywords_sets = [{"Parch", "Cabin", "Pclass"}, {"Sex", "Title"}]
    keywords_sets.append(all_keywords - keywords_sets[0] - keywords_sets[1])

    for keywords in keywords_sets:
        partitions.append(
            df[
                list(
                    {
                        col
                        for col in df.columns
                        for kw in keywords
                        if kw in col or "Survived" in col
                    }
                )
            ]
        )

    return partitions


class ClientModel(nn.Module):
    def __init__(self, input_size):
        super(ClientModel, self).__init__()
        self.fc = nn.Linear(input_size, 4)

    def forward(self, x):
        return self.fc(x)
# Out:
# <>:17: DeprecationWarning: invalid escape sequence '\.'

# %%
import flwr as fl
import torch
from sklearn.preprocessing import StandardScaler

# from task import ClientModel


class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid, data):
        self.cid = cid
        self.train = torch.tensor(StandardScaler().fit_transform(data)).float()
        self.model = ClientModel(input_size=self.train.shape[1])
        self.optimizer = torch.optim.SGD(self.model.parameters(), lr=0.01)
        self.embedding = self.model(self.train)

    def get_parameters(self, config):
        pass

    def fit(self, parameters, config):
        self.embedding = self.model(self.train)
        return [self.embedding.detach().numpy()], 1, {}

    def evaluate(self, parameters, config):
        self.model.zero_grad()
        self.embedding.backward(torch.from_numpy(parameters[int(self.cid)]))
        self.optimizer.step()
        return 0.0, 1, {}

# %% [markdown]
# Strategy

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from flwr.common import ndarrays_to_parameters, parameters_to_ndarrays


class ServerModel(nn.Module):
    def __init__(self, input_size):
        super(ServerModel, self).__init__()
        self.fc = nn.Linear(input_size, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc(x)
        return self.sigmoid(x)


class Strategy(fl.server.strategy.FedAvg):
    def __init__(
        self,
        labels,
        *,
        fraction_fit=1,
        fraction_evaluate=1,
        min_fit_clients=2,
        min_evaluate_clients=2,
        min_available_clients=2,
        evaluate_fn=None,
        on_fit_config_fn=None,
        on_evaluate_config_fn=None,
        accept_failures=True,
        initial_parameters=None,
        fit_metrics_aggregation_fn=None,
        evaluate_metrics_aggregation_fn=None,
    ) -> None:
        super().__init__(
            fraction_fit=fraction_fit,
            fraction_evaluate=fraction_evaluate,
            min_fit_clients=min_fit_clients,
            min_evaluate_clients=min_evaluate_clients,
            min_available_clients=min_available_clients,
            evaluate_fn=evaluate_fn,
            on_fit_config_fn=on_fit_config_fn,
            on_evaluate_config_fn=on_evaluate_config_fn,
            accept_failures=accept_failures,
            initial_parameters=initial_parameters,
            fit_metrics_aggregation_fn=fit_metrics_aggregation_fn,
            evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
        )
        self.model = ServerModel(12)
        self.initial_parameters = ndarrays_to_parameters(
            [val.cpu().numpy() for _, val in self.model.state_dict().items()]
        )
        self.optimizer = optim.SGD(self.model.parameters(), lr=0.01)
        self.criterion = nn.BCELoss()
        self.label = torch.tensor(labels).float().unsqueeze(1)

    def aggregate_fit(
        self,
        rnd,
        results,
        failures,
    ):
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            return None, {}

        # Convert results
        embedding_results = [
            torch.from_numpy(parameters_to_ndarrays(fit_res.parameters)[0])
            for _, fit_res in results
        ]
        embeddings_aggregated = torch.cat(embedding_results, dim=1)
        embedding_server = embeddings_aggregated.detach().requires_grad_()
        output = self.model(embedding_server)
        loss = self.criterion(output, self.label)
        loss.backward()

        self.optimizer.step()
        self.optimizer.zero_grad()

        grads = embedding_server.grad.split([4, 4, 4], dim=1)
        np_grads = [grad.numpy() for grad in grads]
        parameters_aggregated = ndarrays_to_parameters(np_grads)

        with torch.no_grad():
            correct = 0
            output = self.model(embedding_server)
            predicted = (output > 0.5).float()

            correct += (predicted == self.label).sum().item()

            accuracy = correct / len(self.label) * 100

        metrics_aggregated = {"accuracy": accuracy}

        return parameters_aggregated, metrics_aggregated

    def aggregate_evaluate(
        self,
        rnd,
        results,
        failures,
    ):
        return None, {}

# %% [markdown]
# Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    hist = np.load("_static/results/hist.npy", allow_pickle=True).item()
    rounds, values = zip(*hist.metrics_distributed_fit["accuracy"])
    plt.plot(np.asarray(rounds), np.asarray(values))
    plt.savefig("_static/results/accuracy.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-600582fc2db4> in <cell line: 4>()
#       3
#       4 if __name__ == "__main__":
# ----> 5     hist = np.load("_static/results/hist.npy", allow_pickle=True).item()
#       6     rounds, values = zip(*hist.metrics_distributed_fit["accuracy"])
#       7     plt.plot(np.asarray(rounds), np.asarray(values))
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425             own_fid = False
#     426         else:
# --> 427             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428             own_fid = True
#     429
#
# FileNotFoundError: [Errno 2] No such file or directory: '_static/results/hist.npy'

# %% [markdown]
# Simulation

# %%
import flwr as fl
import numpy as np
#from strategy import Strategy
#from client import FlowerClient
from pathlib import Path
#from task import get_partitions_and_label

partitions, label = get_partitions_and_label()


def client_fn(cid):
    return FlowerClient(cid, partitions[int(cid)]).to_client()


# Start Flower server
hist = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=3,
    config=fl.server.ServerConfig(num_rounds=1000),
    strategy=Strategy(label),
)

results_dir = Path("_static/results")
results_dir.mkdir(exist_ok=True)
np.save(str(results_dir / "hist.npy"), hist)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 752]
# INFO:flwr:[ROUND 752]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 753]
# INFO:flwr:[ROUND 753]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 754]
# INFO:flwr:[ROUND 754]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 755]
# INFO:flwr:[ROUND 755]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 756]
# INFO:flwr:[ROUND 756]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 757]
# INFO:flwr:[ROUND 757]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 758]
# INFO:flwr:[ROUND 758]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 759]
# INFO:flwr:[ROUND 759]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 760]
# INFO:flwr:[ROUND 760]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 761]
# INFO:flwr:[ROUND 761]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 762]
# INFO:flwr:[ROUND 762]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 763]
# INFO:flwr:[ROUND 763]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 764]
# INFO:flwr:[ROUND 764]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 765]
# INFO:flwr:[ROUND 765]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 766]
# INFO:flwr:[ROUND 766]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 767]
# INFO:flwr:[ROUND 767]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 768]
# INFO:flwr:[ROUND 768]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 769]
# INFO:flwr:[ROUND 769]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 770]
# INFO:flwr:[ROUND 770]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 771]
# INFO:flwr:[ROUND 771]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 772]
# INFO:flwr:[ROUND 772]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 773]
# INFO:flwr:[ROUND 773]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 774]
# INFO:flwr:[ROUND 774]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 775]
# INFO:flwr:[ROUND 775]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 776]
# INFO:flwr:[ROUND 776]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 777]
# INFO:flwr:[ROUND 777]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 778]
# INFO:flwr:[ROUND 778]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 779]
# INFO:flwr:[ROUND 779]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 780]
# INFO:flwr:[ROUND 780]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 781]
# INFO:flwr:[ROUND 781]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 782]
# INFO:flwr:[ROUND 782]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 783]
# INFO:flwr:[ROUND 783]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 784]
# INFO:flwr:[ROUND 784]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 785]
# INFO:flwr:[ROUND 785]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 786]
# INFO:flwr:[ROUND 786]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 787]
# INFO:flwr:[ROUND 787]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 788]
# INFO:flwr:[ROUND 788]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 789]
# INFO:flwr:[ROUND 789]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 790]
# INFO:flwr:[ROUND 790]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 791]
# INFO:flwr:[ROUND 791]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 792]
# INFO:flwr:[ROUND 792]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 793]
# INFO:flwr:[ROUND 793]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 794]
# INFO:flwr:[ROUND 794]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 795]
# INFO:flwr:[ROUND 795]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 796]
# INFO:flwr:[ROUND 796]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 797]
# INFO:flwr:[ROUND 797]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 798]
# INFO:flwr:[ROUND 798]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 799]
# INFO:flwr:[ROUND 799]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 800]
# INFO:flwr:[ROUND 800]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 801]
# INFO:flwr:[ROUND 801]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 802]
# INFO:flwr:[ROUND 802]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 803]
# INFO:flwr:[ROUND 803]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 804]
# INFO:flwr:[ROUND 804]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 805]
# INFO:flwr:[ROUND 805]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 806]
# INFO:flwr:[ROUND 806]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 807]
# INFO:flwr:[ROUND 807]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 808]
# INFO:flwr:[ROUND 808]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 809]
# INFO:flwr:[ROUND 809]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 810]
# INFO:flwr:[ROUND 810]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 811]
# INFO:flwr:[ROUND 811]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 812]
# INFO:flwr:[ROUND 812]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 813]
# INFO:flwr:[ROUND 813]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 814]
# INFO:flwr:[ROUND 814]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 815]
# INFO:flwr:[ROUND 815]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 816]
# INFO:flwr:[ROUND 816]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 817]
# INFO:flwr:[ROUND 817]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 818]
# INFO:flwr:[ROUND 818]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 819]
# INFO:flwr:[ROUND 819]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 820]
# INFO:flwr:[ROUND 820]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 821]
# INFO:flwr:[ROUND 821]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 822]
# INFO:flwr:[ROUND 822]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 823]
# INFO:flwr:[ROUND 823]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 824]
# INFO:flwr:[ROUND 824]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 825]
# INFO:flwr:[ROUND 825]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 826]
# INFO:flwr:[ROUND 826]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 827]
# INFO:flwr:[ROUND 827]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 828]
# INFO:flwr:[ROUND 828]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 829]
# INFO:flwr:[ROUND 829]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 830]
# INFO:flwr:[ROUND 830]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 831]
# INFO:flwr:[ROUND 831]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 832]
# INFO:flwr:[ROUND 832]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_evaluate: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO:flwr:aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO:flwr:
# INFO :      [ROUND 833]
# INFO:flwr:[ROUND 833]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO:flwr:configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO:flwr:aggregate_fit: received 3 results and 0 failures
# ...
# INFO:flwr:	              (848, 62.429696287964006),
# INFO :      	              (849, 61.19235095613048),
# INFO:flwr:	              (849, 61.19235095613048),
# INFO :      	              (850, 61.64229471316085),
# INFO:flwr:	              (850, 61.64229471316085),
# INFO :      	              (851, 61.64229471316085),
# INFO:flwr:	              (851, 61.64229471316085),
# INFO :      	              (852, 61.754780652418454),
# INFO:flwr:	              (852, 61.754780652418454),
# INFO :      	              (853, 61.97975253093363),
# INFO:flwr:	              (853, 61.97975253093363),
# INFO :      	              (854, 62.76715410573678),
# INFO:flwr:	              (854, 62.76715410573678),
# INFO :      	              (855, 62.65466816647919),
# INFO:flwr:	              (855, 62.65466816647919),
# INFO :      	              (856, 61.754780652418454),
# INFO:flwr:	              (856, 61.754780652418454),
# INFO :      	              (857, 58.71766029246345),
# INFO:flwr:	              (857, 58.71766029246345),
# INFO :      	              (858, 61.754780652418454),
# INFO:flwr:	              (858, 61.754780652418454),
# INFO :      	              (859, 60.8548931383577),
# INFO:flwr:	              (859, 60.8548931383577),
# INFO :      	              (860, 61.97975253093363),
# INFO:flwr:	              (860, 61.97975253093363),
# INFO :      	              (861, 61.86726659167604),
# INFO:flwr:	              (861, 61.86726659167604),
# INFO :      	              (862, 63.554555680539934),
# INFO:flwr:	              (862, 63.554555680539934),
# INFO :      	              (863, 61.86726659167604),
# INFO:flwr:	              (863, 61.86726659167604),
# INFO :      	              (864, 61.86726659167604),
# INFO:flwr:	              (864, 61.86726659167604),
# INFO :      	              (865, 61.754780652418454),
# INFO:flwr:	              (865, 61.754780652418454),
# INFO :      	              (866, 62.20472440944882),
# INFO:flwr:	              (866, 62.20472440944882),
# INFO :      	              (867, 61.64229471316085),
# INFO:flwr:	              (867, 61.64229471316085),
